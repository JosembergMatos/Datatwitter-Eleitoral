# %% [markdown]
# <a href="https://colab.research.google.com/github/JosembergMatos/Datatwitter-Eleitoral/blob/main/Etapa_4_Analise_de_sentimento_jpynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install vaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.7/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (1.24.3)

# %%
import pandas as pd
import re
#Processamento de Linguagem Natural
import nltk
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA

# %%
dataframe_sentimento = pd.read_csv("dataframe_final_candidatos_pronto_para_sentimento.csv")

# %%
dataframe_sentimento.head()
# Out:
#                    Data_Hora              IdTweet  \
# 0  2022-07-30 09:50:40+00:00  1553317140085997568
# 1  2022-07-30 09:50:38+00:00  1553317133756637185
# 2  2022-07-30 09:50:37+00:00  1553317127456686081
# 3  2022-07-30 09:50:36+00:00  1553317123342176257
# 4  2022-07-30 09:50:34+00:00  1553317115175772161
#
#                                                Tweet Candidato  \
# 0  @LulaOficial O senhor não quer governar com ód...      lula
# 1  @UOLNoticias Lula é o melhor preparado para oc...      lula
# 2                              @LulaOficial ##Ladrao      lula
# 3  Isolado, Ciro elogia Lula e sinaliza que esta ...      lula
# 4  @GayerGus trabalho de formiguinha!Mostreis os ...      lula
#
#                                          Tweet_limpo
# 0   o senhor não quer governar com ódio? fique tr...
# 1   lula é o melhor preparado para ocupar a presi...
# 2
# 3  isolado, ciro elogia lula e sinaliza que esta ...
# 4   trabalho de formiguinha!mostreis os vídeos do...

# %%
analisador_de_texto = SentimentIntensityAnalyzer()

# %%
dataframe_sentimento['Sentimentos'] = dataframe_sentimento['Tweet_limpo'].apply(lambda i:analisador_de_texto.polarity_scores(' '.join(re.findall(r'\w+',i.lower()))))

# %%
dataframe_sentimento
# Out:
#                     Data_Hora              IdTweet  \
# 0   2022-07-30 09:50:40+00:00  1553317140085997568
# 1   2022-07-30 09:50:38+00:00  1553317133756637185
# 2   2022-07-30 09:50:37+00:00  1553317127456686081
# 3   2022-07-30 09:50:36+00:00  1553317123342176257
# 4   2022-07-30 09:50:34+00:00  1553317115175772161
# ..                        ...                  ...
# 88  2022-07-30 09:49:59+00:00  1553316969197277185
# 89  2022-07-30 09:49:58+00:00  1553316965053353984
# 90  2022-07-30 09:49:56+00:00  1553316958409555968
# 91  2022-07-30 09:49:54+00:00  1553316949983109121
# 92  2022-07-30 09:49:45+00:00  1553316912712617984
#
#                                                 Tweet Candidato  \
# 0   @LulaOficial O senhor não quer governar com ód...      lula
# 1   @UOLNoticias Lula é o melhor preparado para oc...      lula
# 2                               @LulaOficial ##Ladrao      lula
# 3   Isolado, Ciro elogia Lula e sinaliza que esta ...      lula
# 4   @GayerGus trabalho de formiguinha!Mostreis os ...      lula
# ..                                                ...       ...
# 88  @angelicaut13 @parasamuel @LulaOficial @LulaPT...      lula
# 89         @zizaclandestina @Nilsonhandebol Lula 2022      lula
# 90  @LulaOficial Presidente o senhor w um homem ab...      lula
# 91  Se o Lula continuar subindo nas pesquisas, até...      lula
# 92  @DougHonoratoBr @Antikomunist6 @SmithHays88 @m...      lula
#
#                                           Tweet_limpo  \
# 0    o senhor não quer governar com ódio? fique tr...
# 1    lula é o melhor preparado para ocupar a presi...
# 2
# 3   isolado, ciro elogia lula e sinaliza que esta ...
# 4    trabalho de formiguinha!mostreis os vídeos do...
# ..                                                ...
# 88                                      bom dia angel
# 89                                          lula 2022
# 90   presidente o senhor w um homem abençoado por ...
# 91  se o lula continuar subindo nas pesquisas, até...
# 92      pela milésima vez: não estou defendendo o ...
#
#                                           Sentimentos
# 0   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2   {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4   {'neg': 0.041, 'neu': 0.959, 'pos': 0.0, 'comp...
# ..                                                ...
# 88  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 89  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 90  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 91  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 92  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [93 rows x 6 columns]

# %%
dataframe_sentimento['Sentimentos']
# Out:
# 0     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2     {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 3     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4     {'neg': 0.041, 'neu': 0.959, 'pos': 0.0, 'comp...
#                             ...
# 88    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 89    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 90    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 91    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 92    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# Name: Sentimentos, Length: 93, dtype: object
